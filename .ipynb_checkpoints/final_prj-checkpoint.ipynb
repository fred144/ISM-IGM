# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from astropy import units as u
import astropy.cosmology.units as cu
from astropy.cosmology import FlatLambdaCDM
from matplotlib import colors
import matplotlib as mpl

cosmology = FlatLambdaCDM(H0=70 * u.km / u.s / u.Mpc, Tcmb0=2.725 * u.K, Om0=0.3)

# %%
# %matplotlib inline
mpl.rcParams.update(mpl.rcParamsDefault)
plt.rcParams.update(
    {
        "text.usetex": True,
        # "font.family": "Helvetica",
        "font.family": "serif",
        "mathtext.fontset": "cm",
        "xtick.labelsize": 8,
        "ytick.labelsize": 8,
        "font.size": 8,
        "xtick.direction": "in",
        "ytick.direction": "in",
        "ytick.right": True,
        "xtick.top": True,
        # "axes.linewidth": ,
    }
)

# %% [markdown]
# Here we'll look at two distinct IMFs

# %%
masses = np.geomspace(0.1, 100, 100)


def salp(m, gamma=2.3):
    return m**-gamma


def kroupa(m):
    output = np.zeros_like(m)
    mask1 = (m >= 0.1) & (m < 0.5)
    mask2 = m >= 0.5
    output[mask1] = 2 * m[mask1] ** -1.3
    output[mask2] = m[mask2] ** -2.3
    return output


def top_heavy1(m, alpha=1.7):
    output = np.zeros_like(m)
    mask1 = (m >= 0.1) & (m < 0.5)
    mask2 = m >= 0.5
    output[mask1] = 2 * m[mask1] ** -1.3
    output[mask2] = alpha * m[mask2] ** -alpha
    return output


def top_heavy2(m, alpha):
    output = np.zeros_like(m)
    mask1 = (m >= 0.1) & (m < 0.5)
    mask2 = m >= 0.5
    output[mask1] = 2 * m[mask1] ** -1.35
    output[mask2] = 1.2 * m[mask2] ** -alpha
    return output


fig, ax = plt.subplots(1, 1, dpi=120, figsize=(5, 4))
ax.plot(masses, salp(masses), lw=3, color="rebeccapurple", label="Salpeter 1955")
ax.plot(masses, kroupa(masses), lw=3, color="crimson", label="Kroupa 2001")
ax.plot(
    masses,
    top_heavy2(masses, alpha=2.1),
    lw=3,
    color="grey",
    ls=":",
    label=r"Top Heavy, $\alpha = 2.1$",
)
ax.plot(
    masses,
    top_heavy1(masses, alpha=1.7),
    lw=3,
    color="black",
    ls="--",
    label=r"Top Heavier, $\alpha = 1.7$",
)
ax.set(
    xscale="log",
    yscale="log",
    xlim=(0.1, 100),
    ylim=(1e-3, 200),
    xlabel=r"Stellar Mass [M$_\odot$]",
    ylabel=r"$N$",
)
ax.legend()
plt.show()
plt.savefig("imf.png")

# %% [markdown]
# Here we load the synthetic spectrum, which is tabulated
# ```
# TIME [YR] WAVELENGTH[A]  LOG TOTAL  LOG STELLAR  LOG NEBULAR[ERG/SEC/A]
# ```
# note, for a given time in the `TIME [YR]`, there is an associated wavelength value for each other columns.
#
# So, there are repeating `TIME [YR]` values set for a given age of (e.g.) of which has varying LOG TOTAL LUMINOSITY, etc.

# %%
time, wvlngth, log_total_lum = np.loadtxt(
    "kroupa_metal1e-4/kroupa_metal1e-4.spectrum1", unpack=True, usecols=(0, 1, 2), skiprows=6
)

# convert time
tmyr = time / 1e6
wav_ang = wvlngth

# %% [markdown]
# Here are the actual unique times in Myr, note it is accurate up to around 100 Myr

# %%
np.unique(tmyr)
# Out:
# array([1.000e-02, 2.010e+00, 4.010e+00, 6.010e+00, 8.010e+00, 1.001e+01,
#        1.201e+01, 1.401e+01, 1.601e+01, 1.801e+01, 2.001e+01, 2.201e+01,
#        2.401e+01, 2.601e+01, 2.801e+01, 3.001e+01, 3.201e+01, 3.401e+01,
#        3.601e+01, 3.801e+01, 4.001e+01, 4.201e+01, 4.401e+01, 4.601e+01,
#        4.801e+01, 5.001e+01, 5.201e+01, 5.401e+01, 5.601e+01, 5.801e+01,
#        6.001e+01, 6.201e+01, 6.401e+01, 6.601e+01, 6.801e+01, 7.001e+01,
#        7.201e+01, 7.401e+01, 7.601e+01, 7.801e+01, 8.001e+01, 8.201e+01,
#        8.401e+01, 8.601e+01, 8.801e+01, 9.001e+01, 9.201e+01, 9.401e+01,
#        9.601e+01, 9.801e+01])

# %% [markdown]
# we can wrap this in a function so that we only return the specturm at approximately wanted_time

# %% [markdown]
# while we're at it we can also calculate being able to see how it changes if we place it to a given redshift (z) for a given observed Flux $F_{\rm obs}$ and wavelength $\lambda$
#
# $$
# \lambda_{\rm obs} = \lambda(1+z)
# $$
#
# $$
# F_{\rm obs} = \dfrac{L}{ 4 \pi d_L^2}
# $$
#
# for a given restframe luminosity (which we have from starburst99), luminosity distance, which depends on redshift.

# %%
def get_spectrum(file, wanted_tmyr, type="total"):
    if type == "total":
        time, wvlngth, lum = np.loadtxt(
            file, unpack=True, usecols=(0, 1, 2), skiprows=6
        )
    elif type == "stellar":
        time, wvlngth, lum = np.loadtxt(
            file, unpack=True, usecols=(0, 1, 3), skiprows=6
        )
    elif type == "nebular":
        time, wvlngth, lum = np.loadtxt(
            file, unpack=True, usecols=(0, 1, 4), skiprows=6
        )
    else:
        print("type on valid")
        exit()

    # convert time
    tmyr = time / 1e6
    wav_ang = wvlngth * u.Angstrom

    # since it is a table, get the closest Myr to it
    wanted_idx = np.argmin(np.abs(np.unique(tmyr) - wanted_tmyr))
    closest_time = np.unique(tmyr)[wanted_idx]
    # print("Closest time to wanted time: {} Myr".format(closest_time))
    valid_time_mask = tmyr == closest_time

    wav = wav_ang[valid_time_mask]
    log_total_luminosity = lum[valid_time_mask]
    luminosity = 10**log_total_luminosity * (u.erg / u.s / u.Angstrom)

    return wav.to("micron").value, luminosity.value

# %%
tmyr = 50

def observed_flux_calc(wav, lum, redshift):
    cosmology = FlatLambdaCDM(H0=70 * u.km / u.s / u.Mpc, Tcmb0=2.725 * u.K, Om0=0.3)
    lum_distance = cosmology.luminosity_distance(redshift).to("cm")
    observed_flux = lum / (4 * np.pi * lum_distance**2)
    observed_wavlength = wav * (1 + redshift)
    return observed_wavlength, observed_flux


wav, lum_total = get_spectrum(
    "kroupa_metal1e-4/kroupa_metal1e-4.spectrum1", wanted_tmyr=tmyr, type="total"
)
observed_wavlength, observed_flux = observed_flux_calc(wav, lum_total, redshift=10)

_, lum_stellar = get_spectrum(
    "kroupa_metal1e-4/kroupa_metal1e-4.spectrum1", wanted_tmyr=tmyr, type="stellar"
)
_, observed_flux_stellar = observed_flux_calc(wav, lum_stellar, redshift=10)

_, lum_nebular = get_spectrum(
    "kroupa_metal1e-4/kroupa_metal1e-4.spectrum1", wanted_tmyr=tmyr, type="nebular"
)
_, observed_flux_nebular= observed_flux_calc(wav, lum_nebular, redshift=10)

fig, ax = plt.subplots(
    1,
    2,
    dpi=120,
    figsize=(9, 4),
)
# plot from micron to Angstrom
ax[0]. plot(wav * 1e4, lum_total, color="crimson",
    label="total")
ax[0].plot(
    wav * 1e4,
    lum_stellar,
    color="rebeccapurple",
    label="stellar",
    ls="--"
)
ax[0].plot(
    wav * 1e4,
    lum_nebular,
      color="salmon",
    label="nebular",
   
)
ax[0].set(
    yscale="log",
    ylim=(1e32,2e38),
    xlim=(500,8e3),
    xlabel=r"$\lambda_{\rm rest \, frame}$ [$\mathrm{\AA}$]",
    ylabel=r"$L_{\lambda {\rm rest \, frame}}$ [${\rm erg \: s^{-1} \: \AA^{-1}}$]",
)


ax[1].plot(
    observed_wavlength,
    observed_flux,
    color="crimson",
    label="total"
)
ax[1].plot(
    observed_wavlength,
    observed_flux_stellar,
    color="rebeccapurple",
    label="stellar",
    ls="--"
)
ax[1].plot(
    observed_wavlength,
    observed_flux_nebular,
    color="salmon",
    label="nebular",
    
    
)
ax[1].set(
    xlim=(0.5, 6),
    yscale="log",
    ylim=(1e-29, 2e-22),
    xlabel=r"$\lambda_{\rm obs}$ [$\mu$m]",
    ylabel=r"$F_{\lambda {\rm obs}}$ [${\rm erg \: s^{-1} \: cm^{-2} \AA^{-1}}$]",
)

ax[0].legend()
plt.show()

# %%
# let's loop through all the lines

redshift = 8
tmyrs = np.linspace(0.0, 100, 40)

fig, ax = plt.subplots(1, 3, dpi=150, figsize=(9, 3), sharex=True, sharey=True)
plt.subplots_adjust(hspace=0, wspace=0)
cbar_ax = ax[0].inset_axes([0, 1.02, 3, 0.05])

cmap = plt.cm.inferno_r
norm = colors.Normalize(vmin=np.min(tmyrs), vmax=np.max(tmyrs))
cb = mpl.colorbar.ColorbarBase(
    cbar_ax,
    cmap=cmap,
    norm=norm,
    orientation="horizontal",
)

for t in tmyrs:
    wav, lum = get_spectrum("kroupa_metal1e-4/kroupa_metal1e-4.spectrum1", wanted_tmyr=t)
    observed_wavlength, observed_flux = observed_flux_calc(wav, lum, redshift=10)
    ax[0].plot(observed_wavlength, observed_flux, color=cmap(norm(t)))

for t in tmyrs:
    wav, lum = get_spectrum("topheavy_metal1e-4/topheavy_metal1e-4.spectrum1", wanted_tmyr=t)
    observed_wavlength, observed_flux = observed_flux_calc(wav, lum, redshift=10)
    ax[1].plot(observed_wavlength, observed_flux, color=cmap(norm(t)))
    
for t in tmyrs:
    wav, lum = get_spectrum("topheavier_metal1e-4/topheavier_metal1e-4.spectrum1", wanted_tmyr=t)
    observed_wavlength, observed_flux = observed_flux_calc(wav, lum, redshift=10)
    ax[2].plot(observed_wavlength, observed_flux, color=cmap(norm(t)))

ax[0].set(
    xlim=(0.09, 6.1),
    yscale="log",
    ylim=(1e-26, 1e-19),
    ylabel=r"$F_{\lambda {\rm obs}}$ [${\rm erg \: s^{-1} \: cm^{-2} \AA^{-1}}$]",
)

ax[1].set(xlabel=r"$\lambda_{\rm obs}$ [nm]")
cbar_ax.set(title=r"Galaxy Age [Myr]")
cbar_ax.tick_params(top=True, labeltop=True, bottom=False, labelbottom=False)
ax[0].text(0.95, 0.95, "z = 10", va="top", ha="right", transform=ax[0].transAxes)
ax[0].text(0.05, 0.95, "Kroupa", va="top", ha="left", transform=ax[0].transAxes)
ax[1].text(
    0.05,
    0.95,
    r"Top Heavy, $\alpha  =2.1$",
    va="top",
    ha="left",
    transform=ax[1].transAxes,
)
ax[2].text(
    0.05,
    0.95,
    r"Top Heavier, $\alpha  =1.7$",
    va="top",
    ha="left",
    transform=ax[2].transAxes,
)

# ax.legend(title="Kroupa, z = 10")
plt.savefig("kroupa_spectrum.png")
plt.show()

# %% [markdown]
# Here we show the observed total continuum spectra (stellar + nebular) for a galaxy of mass $10^6~ M_\odot$ at z = 10, colored by the age of the galaxy. The stars have a metallicity of 0.020 $Z_\odot$.

# %% [markdown]
# # Running Cloudy

# %%
import pyCloudy as pc
import os
cosmology = FlatLambdaCDM(H0=70 * u.km / u.s / u.Mpc, Tcmb0=2.725 * u.K, Om0=0.3)

# %%
def run_cloudy(dir, model_name, dens, metallicity, stb99_ascii, age, set_distance:tuple):
    """
    run cloudy using Starburst99 tables, based on Pset1 Problem3
    dir = path to where outputs are to be stored
    model_name = name of the model to be place (as the prefix) of the files in dir
    dens = log10(dens) in cm^-3, uniform
    metals =  hii region abundance in Zsun
    stb99_ascii = path to the starburst99.ascii 
    age = age in years passed as a str; e.g. "1e6" for 1 Myr
    set_distance = unit can be 'kpc', 'Mpc', 'parsecs', 'cm'; e.g. (1, "Mpc")
    """
    pc.config.cloudy_exe = "/home/fabg/Cloudy/c23.01/source/cloudy.exe"

    if not os.path.exists(dir):
        print("> creating container", dir)
        os.makedirs(dir)
    full_model_name = os.path.join(dir, model_name)
    
    abundance_predef = "ism"  # Use pre-defined hii region abundances
    r_min = 5e16  # cm Inner radius (use as default)
    # dens = 3. #log cm-3, we'll assume uniform density
    # metals = 1   # Metal scaling for abundances (
    # r_max = 2e18 # cm  # Outer radius (if needed)
    # dist = 1.0  # kpc, only used for final output spectra
    
    # fmt: off
    options = (
        "no molecules", "no level2 lines", "no fine opacities",
        "atom h-like levels small", "atom he-like levels small",
        "COSMIC RAY BACKGROUND", "element limit off -8", "print line optical depth",
        "table stars \"{}\" age={} years".format(stb99_ascii, age),
        "luminosity total 38"
         # "table star \"{}\" 24300 4.3".format(stb99_ascii)
    )
     # fmt: on
    # emission lines that we may be using for analysis of model outputs
    # fmt: off
    emis_tab = [
        "H  1  4861.33A", "H  1  6562.81A", "Ca B  5875.64A", "N  2  6583.45A",
        "N  2  5756.20A", "N  2  6585.30A", "O  1  6300.30A", "O  2  3726.03A",
        "O  2  3727.10A", "O  2  3729.80A", "O  2  3728.81A", "S  2  6716.44A",
        "S  2  6718.30A", "S  2  6730.82A", "S  2  6732.70A", "O  3  4364.40A",  
        "O  3  5006.84A", "O  3  5008.20A", "BLND  4363.00A", "Cl 3  5517.71A",
        "Cl 3  5537.87A", "O  1  63.1679m", "O  1  145.495m", "C  2  157.636m",
    ]
    # fmt: on
    
    # Defining the object that will manage the input file for Cloudy
    c_input = pc.CloudyInput(full_model_name)

    # Filling the object with the parameters
    # Defining the ionizing SED: Effective temperature and luminosity.
    # The lumi_unit is one of the Cloudy options, 
    # like "luminosity solar", "q(H)", "ionization parameter", etc...
    
    qH = 48.75  # Rate of production of Hydrogen ionizing photons in log photons s^-1
    Teff= 1e6#36870.0
    # c_input.set_BB(Teff=Teff, lumi_unit="q(H)", lumi_value=qH)
    
    # elif config == "seyfert":
    #     c_input.set_star()
    #     c_input.set_star(
    #         SED="table star",
    #         SED_params="",
    #         lumi_unit="ionization parameter",
    #         lumi_value=-2,
    #     )

    # Defining the density and profile
    c_input.set_cste_density(dens)  # constant density

    # Defining the inner radius. 
    # A second parameter could be the outer radius (matter-bounded nebula).
    # c_input.set_radius(r_in=np.log10(r_min),r_out=np.log10(r_max))
    c_input.set_radius(r_in=np.log10(r_min))
    
    # Use pre-defined hii region abundances
    c_input.set_abund( predef=abundance_predef, nograins=True, metals=metallicity)  
    
    # Other options from above
    c_input.set_other(options)
    
    # (0) for no iteration, () for one iteration, (N) for N iterations.
    c_input.set_iterate(100) 
    
    # () or (True) : sphere, or (False): open geometry.
    c_input.set_sphere(True)  
    
    c_input.set_emis_tab(emis_tab) 

    c_input.set_distance(*set_distance, linear=True)  
    # Writing the Cloudy inputs. 
    # to_file for writing to a file (named by full_model_name). verbose to print on the screen.
    c_input.print_input(to_file=True, verbose=False)

    # Printing some message to the screen
    pc.log_.message("Running {0}".format(model_name), calling=model_name)

    # Running Cloudy with a timer. Here we reset it to 0.
    pc.log_.timer("Starting Cloudy", quiet=True, calling=model_name)
    c_input.run_cloudy()
    pc.log_.timer("Cloudy ended after seconds:", calling=model_name)

# %% [markdown]
# ### Let's set the distance of this object at redshift z = 10
# We can run the the model at a density of $10^4~ cm^{-3}$ and starting at a low metallicity of $0.0001 Z_\odot$ and is 1 Myr at that time.
# We also set the total luminosity of the star cluster at $10^{38}$ ergs/s. And ISM abundances

# %%
print(cosmology.luminosity_distance(10).to("Mpc"))
# Out:
# 103795.79630242278 Mpc

# %%
run_cloudy(dir="./topheavy_metal1e-4/", 
           model_name="cloudy_topheavy_metal1e-4", 
           dens=4.0, 
           metallicity=1e-4, 
           stb99_ascii="./topheavy_metal1e-4/starburst99.ascii", 
           age= "1e6", 
           set_distance=(1e5, "Mpc"))
# Out:
# #####################################
# title cloudy_topheavy_metal1e-4
# #####################################
# set punch prefix "cloudy_topheavy_metal1e-4"
# radius = 16.699
# hden = 4.000
# filling factor = 1.0
# abundances ism no grains
# metals 0.0001
# distance = 100000000000.0 parsecs linear
# no molecules
# no level2 lines
# no fine opacities
# atom h-like levels small
# atom he-like levels small
# COSMIC RAY BACKGROUND
# element limit off -8
# print line optical depth
# table stars "./topheavy_metal1e-4/starburst99.ascii" age=1e6 years
# luminosity total 38
# iterate 100
# sphere
# save last radius ".rad"
# save last continuum ".cont"
# save last physical conditions ".phy"
# save last overview ".ovr"
# save last heating ".heat"
# save last cooling ".cool"
# save last optical depth ".opd"
# save last element hydrogen ".ele_H"
# save last element helium ".ele_He"
# save last element carbon ".ele_C"
# save last element nitrogen ".ele_N"
# save last element oxygen ".ele_O"
# save last element argon ".ele_Ar"
# save last element neon ".ele_Ne"
# save last element sulphur ".ele_S"
# save last element chlorin ".ele_Cl"
# save last element iron ".ele_Fe"
# save last element silicon ".ele_Si"
# save last lines emissivity  ".emis"
# H  1  4861.33A
# H  1  6562.81A
# Ca B  5875.64A
# N  2  6583.45A
# N  2  5756.20A
# N  2  6585.30A
# O  1  6300.30A
# O  2  3726.03A
# O  2  3727.10A
# O  2  3729.80A
# O  2  3728.81A
# S  2  6716.44A
# S  2  6718.30A
# S  2  6730.82A
# S  2  6732.70A
# O  3  4364.40A
# O  3  5006.84A
# O  3  5008.20A
# BLND  4363.00A
# Cl 3  5517.71A
# Cl 3  5537.87A
# O  1  63.1679m
# O  1  145.495m
# C  2  157.636m
# end of lines
#    cloudy_topheavy_metal1e-4: Cloudy ended after seconds: in 569.5710504055023

# %%
run_cloudy(dir="./topheavier_metal1e-4/", 
           model_name="cloudy_topheavier_metal1e-4", 
           dens=4.0, 
           metallicity=1e-4, 
           stb99_ascii="./topheavier_metal1e-4/starburst99.ascii", 
           age= "1e6", 
           set_distance=(1e5, "Mpc"))
# Out:
# #####################################
# title cloudy_topheavier_metal1e-4
# #####################################
# set punch prefix "cloudy_topheavier_metal1e-4"
# radius = 16.699
# hden = 4.000
# filling factor = 1.0
# abundances ism no grains
# metals 0.0001
# distance = 100000000000.0 parsecs linear
# no molecules
# no level2 lines
# no fine opacities
# atom h-like levels small
# atom he-like levels small
# COSMIC RAY BACKGROUND
# element limit off -8
# print line optical depth
# table stars "./topheavier_metal1e-4/starburst99.ascii" age=1e6 years
# luminosity total 38
# iterate 100
# sphere
# save last radius ".rad"
# save last continuum ".cont"
# save last physical conditions ".phy"
# save last overview ".ovr"
# save last heating ".heat"
# save last cooling ".cool"
# save last optical depth ".opd"
# save last element hydrogen ".ele_H"
# save last element helium ".ele_He"
# save last element carbon ".ele_C"
# save last element nitrogen ".ele_N"
# save last element oxygen ".ele_O"
# save last element argon ".ele_Ar"
# save last element neon ".ele_Ne"
# save last element sulphur ".ele_S"
# save last element chlorin ".ele_Cl"
# save last element iron ".ele_Fe"
# save last element silicon ".ele_Si"
# save last lines emissivity  ".emis"
# H  1  4861.33A
# H  1  6562.81A
# Ca B  5875.64A
# N  2  6583.45A
# N  2  5756.20A
# N  2  6585.30A
# O  1  6300.30A
# O  2  3726.03A
# O  2  3727.10A
# O  2  3729.80A
# O  2  3728.81A
# S  2  6716.44A
# S  2  6718.30A
# S  2  6730.82A
# S  2  6732.70A
# O  3  4364.40A
# O  3  5006.84A
# O  3  5008.20A
# BLND  4363.00A
# Cl 3  5517.71A
# Cl 3  5537.87A
# O  1  63.1679m
# O  1  145.495m
# C  2  157.636m
# end of lines
#    cloudy_topheavier_metal1e-4: Cloudy ended after seconds: in 492.4335389137268

# %%
run_cloudy(dir="./kroupa_metal1e-4/", 
           model_name="cloudy_kroupa_metal1e-4", 
           dens=4.0, 
           metallicity=1e-4, 
           stb99_ascii="./kroupa_metal1e-4/starburst99.ascii", 
           age= "1e6", 
           set_distance=(1e5, "Mpc"))
# Out:
# #####################################
# title cloudy_kroupa_metal1e-4
# #####################################
# set punch prefix "cloudy_kroupa_metal1e-4"
# radius = 16.699
# hden = 4.000
# filling factor = 1.0
# abundances ism no grains
# metals 0.0001
# distance = 100000000000.0 parsecs linear
# no molecules
# no level2 lines
# no fine opacities
# atom h-like levels small
# atom he-like levels small
# COSMIC RAY BACKGROUND
# element limit off -8
# print line optical depth
# table stars "./kroupa_metal1e-4/starburst99.ascii" age=1e6 years
# luminosity total 38
# iterate 100
# sphere
# save last radius ".rad"
# save last continuum ".cont"
# save last physical conditions ".phy"
# save last overview ".ovr"
# save last heating ".heat"
# save last cooling ".cool"
# save last optical depth ".opd"
# save last element hydrogen ".ele_H"
# save last element helium ".ele_He"
# save last element carbon ".ele_C"
# save last element nitrogen ".ele_N"
# save last element oxygen ".ele_O"
# save last element argon ".ele_Ar"
# save last element neon ".ele_Ne"
# save last element sulphur ".ele_S"
# save last element chlorin ".ele_Cl"
# save last element iron ".ele_Fe"
# save last element silicon ".ele_Si"
# save last lines emissivity  ".emis"
# H  1  4861.33A
# H  1  6562.81A
# Ca B  5875.64A
# N  2  6583.45A
# N  2  5756.20A
# N  2  6585.30A
# O  1  6300.30A
# O  2  3726.03A
# O  2  3727.10A
# O  2  3729.80A
# O  2  3728.81A
# S  2  6716.44A
# S  2  6718.30A
# S  2  6730.82A
# S  2  6732.70A
# O  3  4364.40A
# O  3  5006.84A
# O  3  5008.20A
# BLND  4363.00A
# Cl 3  5517.71A
# Cl 3  5537.87A
# O  1  63.1679m
# O  1  145.495m
# C  2  157.636m
# end of lines
#    cloudy_kroupa_metal1e-4: Cloudy ended after seconds: in 476.31843852996826

# %%
run_cloudy(dir="./kroupa_metal1e-4_10Myr/", 
           model_name="kroupa_metal1e-4_10Myr", 
           dens=4.0, 
           metallicity=1e-4, 
           stb99_ascii="./kroupa_metal1e-4_10Myr/starburst99.ascii", 
           age= "1e7", 
           set_distance=(1e5, "Mpc"))

run_cloudy(dir="./topheavy_metal1e-4_10Myr/", 
           model_name="topheavy_metal1e-4_10Myr", 
           dens=4.0, 
           metallicity=1e-4, 
           stb99_ascii="./topheavy_metal1e-4_10Myr/starburst99.ascii", 
           age= "1e7", 
           set_distance=(1e5, "Mpc"))

run_cloudy(dir="./topheavier_metal1e-4_10Myr/", 
           model_name="topheavier_metal1e-4_10Myr", 
           dens=4.0, 
           metallicity=1e-4, 
           stb99_ascii="./topheavier_metal1e-4_10Myr/starburst99.ascii", 
           age= "1e7", 
           set_distance=(1e5, "Mpc"))

# %%
heavy_model= pc.CloudyModel(os.path.join("./topheavy_metal1e-4/", "cloudy_topheavy_metal1e-4") )
heavy_ne = model.ne
heavy_te = model.te
heavy_incident = model.get_cont_y(cont="incid", unit="Jy")
heavy_diffuse = model.get_cont_y(cont="diffout", unit="Jy")
heavy_net_transmitted = model.get_cont_y(cont="ntrans", unit="Jy")
heavy_wav_ang = model.get_cont_x(unit="Ang")

heavier_model= pc.CloudyModel(os.path.join("./topheavier_metal1e-4/", "cloudy_topheavier_metal1e-4"))
heavier_ne = model.ne
heavier_te = model.te
heavier_incident = model.get_cont_y(cont="incid", unit="Jy")
heavier_diffuse = model.get_cont_y(cont="diffout", unit="Jy")
heavier_net_transmitted = model.get_cont_y(cont="ntrans", unit="Jy")
heavier_wav_ang = model.get_cont_x(unit="Ang")

kroupa_model= pc.CloudyModel(os.path.join("./kroupa_metal1e-4/", "cloudy_kroupa_metal1e-4"))
kroupa_ne = model.ne
kroupa_te = model.te
kroupa_incident = model.get_cont_y(cont="incid", unit="Jy")
kroupa_diffuse = model.get_cont_y(cont="diffout", unit="Jy")
kroupa_net_transmitted = model.get_cont_y(cont="ntrans", unit="Jy")
kroupa_wav_ang = model.get_cont_x(unit="Ang")

fig, ax = plt.subplots(1, 3, dpi=150, figsize=(9, 3), sharex=True, sharey=True)
plt.subplots_adjust(hspace=0, wspace=0)

ax[0].plot(kroupa_wav_ang, kroupa_incident, color="indigo", label="incident")
ax[0].plot(kroupa_wav_ang, kroupa_diffuse, color="crimson", lw=0.8, label="diffused")
ax[0].plot(kroupa_wav_ang, kroupa_net_transmitted, color="gold", lw=0.8, label="net transmitted")

ax[1].plot(heavy_wav_ang, heavy_incident, color="indigo", label="incident")
ax[1].plot(heavy_wav_ang, heavy_diffuse, color="crimson", lw=0.8, label="diffused")
ax[1].plot(heavy_wav_ang, heavy_net_transmitted, color="gold", lw=0.8, label="net transmitted")

ax[2].plot(heavier_wav_ang, heavier_incident, color="indigo", label="incident")
ax[2].plot(heavier_wav_ang, heavier_diffuse, color="crimson", lw=0.8, label="diffused")
ax[2].plot(heavier_wav_ang, heavier_net_transmitted, color="gold", lw=0.8, label="net transmitted")

ax[0].set(ylabel="Intensity [Jy]")
ax[1].set(
    xscale="log",
    yscale="log",
    xlabel=r"$\lambda_{\rm restframe}$ [${\rm \AA}$]",
    xlim=(200, 5e4),
    ylim=(1e-18, 2e-13),
)

ax[0].text(
    0.95,
    0.95,
    r"Kroupa",
    va="top",
    ha="right",
    transform=ax[0].transAxes,
)
ax[1].text(
    0.95,
    0.95,
    r"Top Heavy, $\alpha  =2.1$",
    va="top",
    ha="right",
    transform=ax[1].transAxes,
)
ax[2].text(
    0.95,
    0.95,
    r"Top Heavier, $\alpha  =1.7$",
    va="top",
    ha="right",
    transform=ax[2].transAxes,
)
ax[1].legend()
plt.show()
